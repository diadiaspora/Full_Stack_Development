# %%
def manage_students():
    students = ["bobby", "ricky", "george", "harry"]

    first_student = students[0]
    last_student = students[-1]
    return first_student, last_student, students

print(manage_students())
# Out:
# ('bobby', 'harry', ['bobby', 'ricky', 'george', 'harry'])
