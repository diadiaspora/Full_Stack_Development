# %% [markdown]
# https://pages.git.generalassemb.ly/modular-curriculum-all-courses/python-for-javascript-developers-control-flow-lab/canvas-landing-pages/seb.html

# %% [markdown]
# ## Exercise 1

# %%
def print_greeting():
    # Your code goes here. Remember to indent!
    python_is_fun = True
    if python_is_fun:
        print("Python is fun!")

# %%
print_greeting()
# Out:
# Python is fun!

# %% [markdown]
# Exercise 2

# %%
def check_letter():
    letter = input("Enter a letter:")
    print("This is your letter:", letter)

# %%
check_letter()
# Out:
# Enter a letter: B
# This is your letter: B

# %%
def check_letter():
    letter = input("Enter a letter:")
    print("This is your letter:", letter.upper())

# %%
check_letter()
# Out:
# Enter a letter: x
# This is your letter: X

# %%
def check_letter():
    letter = input("Enter a letter:")
    vowels = [a, e, i, o, u]
    letter in vowels

# %%
check_letter()
# Out:
# Enter a letter: a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 check_letter()
#
# Cell In[7], line 3, in check_letter()
#       1 def check_letter():
#       2     letter = input("Enter a letter:")
# ----> 3     vowels = [a, e, i, o, u]
#       4     letter in vowels
#
# NameError: name 'a' is not defined

# %%
def check_letter():
    letter = input("Enter a letter:")
    vowels = [10, 11, 12, 13, 14]
    letter in vowels

# %%
check_letter()
# Out:
# Enter a letter: a

# %%
check_letter()
# Out:
# Enter a letter: 11

# %%
a = [20, 45, 10]
10 not in a
# Out:
# False

# %%
letter = [20, 45, 10]
letter not in a
# Out:
# True

# %%
def check_letter():
    letter = input("Enter a letter:")
    vowels = [10, 11, 12, 13, 14]
    letter in vowels

# %%
check_letter()
# Out:
# Enter a letter: a

# %%
def check_letter():
    letter = input("Enter a letter:")
    vowels = ["a", "e", "i", "o", "u"]
    if letter in vowels: 
        print("letter is a vowel")

# %%
check_letter()
# Out:
# Enter a letter: a

# %%
check_letter()
# Out:
# Enter a letter: a
# letter is a vowel

# %%
check_letter()
# Out:
# Enter a letter: h

# %%
def check_letter():
    letter = input("Enter a letter:").upper()
    vowels = ["A", "E", "I", "O", "U"]
    if letter in vowels: 
        print("letter is a vowel")
    else:
        print('letter is a consonant')

# %%
check_letter()
# Out:
# Enter a letter: y
# letter is a consonant

# %%
check_letter()
# Out:
# Enter a letter: e
# letter is a consonant

# %%
def check_letter():
    letter = input("Enter a letter:").upper()
    vowels = ["A", "E", "I", "O", "U"]
    if letter in vowels: 
        print("letter is a vowel")
    else:
        print('letter is a consonant')

# %%
check_letter()
# Out:
# Enter a letter: e
# letter is a vowel

# %%
check_letter()
# Out:
# Enter a letter: t
# letter is a consonant

# %%
def check_letter():
    letter = input("Enter a letter:").upper()
    vowels = ["A", "E", "I", "O", "U"]
    if letter in vowels: 
        print(f"{letter} is a vowel")
    else:
        print(f"{letter} is a consonant")

# %%
check_letter()
# Out:
# Enter a letter: g
# G is a consonant

# %%
check_letter()
# Out:
# Enter a letter: i
# I is a vowel

# %%
def check_letter():
    letter = input("Enter a letter:").upper()
    vowels = ["A", "E", "I", "O", "U"]
    if letter in vowels: 
        print(f"{letter} is a vowel")
    elif letter not in vowels:
        print(f"{letter} is a consonant")
    else:
        print(f"{letter} is not a letter")

# %%
check_letter()
# Out:
# Enter a letter: g
# G is a consonant

# %%
check_letter()
# Out:
# Enter a letter: =
# = is a consonant

# %%
def check_letter():
    letter = input("Enter a letter:").upper()
    vowels = ["A", "E", "I", "O", "U"]

    if letter.isalpha():
        if letter in vowels: 
            print(f"{letter} is a vowel")
        else: 
            print(f"{letter} is a consonant")
    else:
        print(f"{letter} is not a letter")

# %%
check_letter()
# Out:
# Enter a letter: 0
# 0 is not a letter

# %%
check_letter()
# Out:
# Enter a letter: a
# A is a vowel

# %%
check_letter()
# Out:
# Enter a letter: b
# B is a consonant

# %% [markdown]
# ## Exercise 2

# %%
def check_voting_eligibility():
    age = input("Please enter your age:")

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 21

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")
    age = int(age_input)

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 25

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")
    age = int(age_input)
    print type(age)
# Out:
#   Cell In[52], line 4
#     print type(age)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")
    age = int(age_input)
    print(type(age))

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 5
# <class 'int'>

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")
    age = int(age_input)
    print(type(age))
    print(type(age))

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 8
# <class 'str'>
# <class 'int'>

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")

    if age_input.isdigit():
        age = int(age_input)
        print(type(age))
        print(type(age))
        print("Your age is:", age)
    else:
        print("Not a valid age!")

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 8
# <class 'int'>
# <class 'int'>

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 9
# <class 'int'>
# <class 'int'>

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 12
# <class 'int'>
# <class 'int'>

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")

    if age_input.isdigit():
        age = int(age_input)
        print(type(age))
        print(type(age))
        print(f"Your age is {age}")
    else:
        print("Not a valid age!")

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 10
# <class 'int'>
# <class 'int'>
# Your age is 10

# %%
def check_voting_eligibility():
    age_input = input("Please enter your age:")

    if age_input.isdigit():
        age = int(age_input)
        print(type(age))
        print(type(age))
        print(f"Your age is {age}")
        if age > 18:
            print("You are eligible to vote!")
        else: 
            print("You are not eligible to vote!")
    else:
        print("Not a valid age!")

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 35
# <class 'int'>
# <class 'int'>
# Your age is 35
# You are eligible to vote!

# %%
check_voting_eligibility()
# Out:
# Please enter your age: 6
# <class 'int'>
# <class 'int'>
# Your age is 6
# You are not eligible to vote!

# %% [markdown]
# ## Exercise 3

# %%
def calculate_dog_years():
    input("Enter your dogs name:")

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Chico

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_years_age = input("Enter your dogs age:")

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Alex
# Enter your dogs age: 5

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_years_age = input("Enter your dogs age:")
    print(dogs_name)
    print(dog_years_age)

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Brownie
# Enter your dogs age: 6
# Brownie
# 6

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_years_age = input("Enter your dogs age:")
    print(dogs_name)
    print(type(dog_years_age))

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Biscuit
# Enter your dogs age: 4
# Biscuit
# <class 'str'>

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_years_age = input("Enter your dogs age:")
    dog_years = int(dog_years_age)
    print(dogs_name)
    print(type(dog_years_age))

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Blue
# Enter your dogs age: 9
# Blue
# <class 'str'>

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_years_age = input("Enter your dogs age:")
    dog_years = int(dog_years_age)
    print(dogs_name)
    print(type(dog_years_age))
    print(dog_years)
    print(type(dog_years))

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Tilly
# Enter your dogs age: 3
# Tilly
# <class 'str'>
# 3
# <class 'int'>

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_age = input("Enter your dogs age:")
    age = int(dog_age)
    
    print(dogs_name)
    print(type(dog_age))
    print(age)
    print(type(age))

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Henry
# Enter your dogs age: 4
# Henry
# <class 'str'>
# 4
# <class 'int'>

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_age = input("Enter your dogs age:")
    age = int(dog_age)

    if age < 2:
        dog_years = age * 10
    else:
        dog_years = 20 + ((age - 2) * 7)
    
    print(dogs_name)
    print(type(dog_age))
    print(age)
    print(type(age))
    print(dog_years)

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Nope
# Enter your dogs age: 5
# Nope
# <class 'str'>
# 5
# <class 'int'>
# 50

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_age = input("Enter your dogs age:")
    age = int(dog_age)

    if age > 2:
        dog_years = age * 10
    else:
        dog_years = 20 + ((age - 2) * 7)
    
    print(dogs_name)
    print(type(dog_age))
    print(age)
    print(type(age))
    print(dog_years)

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: lo
# Enter your dogs age: 5
# lo
# <class 'str'>
# 5
# <class 'int'>
# 50

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_age = input("Enter your dogs age:")
    age = int(dog_age)

    if age > 2:
        dog_years = age * 10
    else:
        dog_years = 20 + ((age - 2) * 7)
    print(dog_years)

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: goolash
# Enter your dogs age: 9
# 90

# %%
def calculate_dog_years():
    dogs_name = input("Enter your dogs name:")
    dog_age = input("Enter your dogs age:")
    age = int(dog_age)

    if age < 2:
        dog_years = age * 10
    else:
        dog_years = 20 + ((age - 2) * 7)
    print(dog_years)

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Aggy
# Enter your dogs age: 9
# 69

# %%
calculate_dog_years()
# Out:
# Enter your dogs name: Bo
# Enter your dogs age: 4
# 34

# %% [markdown]
# ## Exercise 4

# %%
def weather_advice():
    cold = input("Is it cold? (yes/no):").lower()
    raining = input("Is it raining? (yes/no):").lower()

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): Yes
# Is it raining? (yes/no): Yes

# %%
def weather_advice():
    cold = input("Is it cold? (yes/no):").lower()
    raining = input("Is it raining? (yes/no):").lower()
    print(cold)
    print(raining)

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): Yes
# Is it raining? (yes/no): No
# yes
# no

# %%
def weather_advice():
    cold = input("Is it cold? (yes/no):").lower()
    raining = input("Is it raining? (yes/no):").lower()
    print(cold)
    print(raining)

    if cold = yes and raining = yes:
        print("Wear a waterproof coat.")
# Out:
#   Cell In[116], line 7
#     if cold = yes and raining = yes:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 weather_advice()
#
# Cell In[114], line 7, in weather_advice()
#       4 print(cold)
#       5 print(raining)
# ----> 7 if cold == yes and raining == yes:
#       8     print("Wear a waterproof coat.")
#
# NameError: name 'yes' is not defined

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == yes

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == yes

    print(cold)

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 weather_advice()
#
# Cell In[125], line 7, in weather_advice()
#       4 print(is_cold)
#       5 print(is_raining)
# ----> 7 cold = is_cold == yes
#       9 print(cold)
#
# NameError: name 'yes' is not defined

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == "yes"

    print(cold)

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes
# True

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == "yes"
    raining = is_raining == "yes"

    print(cold)
    print(raining)

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes
# True
# True

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == "yes"
    raining = is_raining == "yes"

    print(cold)
    print(raining)

    if cold and raining: 
        print ("Wear a waterproof coat.")

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): yes
# yes
# yes
# True
# True
# Wear a waterproof coat.

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == "yes"
    raining = is_raining == "yes"

    print(cold)
    print(raining)

    if cold and raining: 
        print ("Wear a waterproof coat.")
    elif cold and not raining:
        print ("Wear a warm coat.")

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): yes
# Is it raining? (yes/no): no
# yes
# no
# True
# False
# Wear a warm coat.

# %%
def weather_advice():
    is_cold = input("Is it cold? (yes/no):").lower()
    is_raining = input("Is it raining? (yes/no):").lower()
    print(is_cold)
    print(is_raining)

    cold = is_cold == "yes"
    raining = is_raining == "yes"

    print(cold)
    print(raining)

    if cold and raining: 
        print ("Wear a waterproof coat.")
    elif cold and not raining:
        print ("Wear a warm coat.")
    elif not cold and raining:
        print ("Carry an umbrella.")
    else:
        print ("Wear light clothing.")

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): no
# Is it raining? (yes/no): yes
# no
# yes
# False
# True
# Carry an umbrella.

# %%
weather_advice()
# Out:
# Is it cold? (yes/no): no
# Is it raining? (yes/no): no
# no
# no
# False
# False
# Wear light clothing.

# %% [markdown]
# ## Exercise 5

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 11

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    winter = ("Jan", "Feb", "Mar")
    spring = ("Apr", "May", "Jun")
    summer = ("Jul", "Aug", "Sep")
    fall = ("Oct", "Nov", "Dec")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 1

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input
    winter = ("Jan", "Feb", "Mar")
    spring = ("Apr", "May", "Jun")
    summer = ("Jul", "Aug", "Sep")
    fall = ("Oct", "Nov", "Dec")
    print(month_output)

# %%
determine_season()
# Out:
# Enter the month: February
# Enter the day: 3
# February

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    winter = ("Jan", "Feb", "Mar")
    spring = ("Apr", "May", "Jun")
    summer = ("Jul", "Aug", "Sep")
    fall = ("Oct", "Nov", "Dec")
    print(month_output)

# %%
determine_season()
# Out:
# Enter the month: August
# Enter the day: 10
# AUGUST

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)

# %%
determine_season()
# Out:
# Enter the month: December
# Enter the day: 4
# DECEMBER

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)

# %%
determine_season()
# Out:
# Enter the month: October
# Enter the day: 10
# OCTOBER
# OCT

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]

    seasons = { "winter" : "JAN FEB MAR", "spring" : "APR MAY JUN", "summer" : "JUL AUG SEP", "fall" : "OCT NOV DEC" }
   
    print(month_output)
    print(month)

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)

    if month in winter:
        print(winter)

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 1
# JANUARY
# JAN
# ('JAN', 'FEB', 'MAR')

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)

    if month in winter:
        print("Winter")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 1
# JANUARY
# JAN
# winter

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)

    if month in winter:
        print("Winter")
    elif month in spring:
        print("Spring")
    elif month in summer:
        print("Summer")
    else:
        print("Fall")

# %%
determine_season()
# Out:
# Enter the month: August
# Enter the day: 1
# AUGUST
# AUG
# Summer

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    
    winter = ("JAN", "FEB", "MAR")
    spring = ("APR", "MAY", "JUN")
    summer = ("JUL", "AUG", "SEP")
    fall = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)
    print(type(day))
    print(day)

    if month in winter:
        print("Winter")
    elif month in spring:
        print("Spring")
    elif month in summer:
        print("Summer")
    else:
        print("Fall")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 1
# JANUARY
# JAN
# <class 'int'>
# 1
# Winter

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    
    winter_months = ("JAN", "FEB", "MAR") 
    spring_months = ("APR", "MAY", "JUN")
    summer_months = ("JUL", "AUG", "SEP")
    fall_months = ("OCT", "NOV", "DEC")
    print(month_output)
    print(month)
    print(type(day))
    print(day)

    if month in winter_months:
        print("winter_month")
    elif month in spring_months:
        print("Spring")
    elif month in summer_months:
        print("Summer")
    else:
        print("Fall")

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    print(month_output)
    print(month)
    print(type(day))
    print(day)
   

    if month == "DEC" and day > 21 :
        print("Winter")

# %%
determine_season()
# Out:
# Enter the month: December
# Enter the day: 1
# DECEMBER
# DEC
# <class 'int'>
# 1

# %%
determine_season()
# Out:
# Enter the month: December
# Enter the day: 22
# DECEMBER
# DEC
# <class 'int'>
# 22
# Winter

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    print(month_output)
    print(month)
    print(type(day))
    print(day)
   

    if month == "DEC" and day > 21 or month == "JAN" or "FEB":
        print("Winter")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 1
# JANUARY
# JAN
# <class 'int'>
# 1
# Winter

# %%
determine_season()
# Out:
# Enter the month: February
# Enter the day: 1
# FEBRUARY
# FEB
# <class 'int'>
# 1
# Winter

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    print(month_output)
    print(month)
    print(type(day))
    print(day)
   

    if month == "DEC" and day > 21 or month == "JAN" or "FEB" or month == "MAR" and day < 19:
        print("Winter")

# %%
determine_season()
# Out:
# Enter the month: January
# Enter the day: 5
# JANUARY
# JAN
# <class 'int'>
# 5
# Winter

# %%
determine_season()
# Out:
# Enter the month: March
# Enter the day: 6
# MARCH
# MAR
# <class 'int'>
# 6
# Winter

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    print(month_output)
    print(month)
    print(type(day))
    print(day)
   

    if month == ("DEC" and day >= 21) or month in ("JAN" or "FEB") or month == ("MAR" and day <= 19):
        print("Winter") 
    elif month == ("MAR" and day >= 20) or month in ("APR" or "MAY") or month == ("JUN" and day <= 20):
        print("Spring") 
    elif month == ("JUL" and day >= 21) or month in "AUG" or "SEP" or (month == "OCT" and day <= 21):
        print("Summer") 
    else: 
        print("Fall")

# %%
determine_season()
# Out:
# Enter the month: July
# Enter the day: 5
# JULY
# JUL
# <class 'int'>
# 5
# Summer

# %%
determine_season()
# Out:
# Enter the month: April
# Enter the day: 5
# APRIL
# APR
# <class 'int'>
# 5
# Spring

# %%
def determine_season():
    month_input = input("Enter the month:")
    day_input = input("Enter the day:")
    month_output = month_input.upper()
    month = month_output[:3]
    day = int(day_input)
    print(month_output)
    print(month)
    print(type(day))
    print(day)
   

    if month == ("DEC" and day >= 21) or month in ("JAN" or "FEB") or month == ("MAR" and day <= 19):
        print(f"{month_output} {day} is in Winter") 
    elif month == ("MAR" and day >= 20) or month in ("APR" or "MAY") or month == ("JUN" and day <= 20):
        print(f"{month_output} {day} is in Spring") 
    elif month == ("JUL" and day >= 21) or month in "AUG" or "SEP" or (month == "OCT" and day <= 21):
        print(f"{month_output} {day} is in Summer") 
    else: 
        print(f"{month_output} {day} is in Fall")

# %%
determine_season()
# Out:
# Enter the month: April
# Enter the day: 5
# APRIL
# APR
# <class 'int'>
# 5
# APRIL 5 is in Spring

# %% [markdown]
# Exercise 6

# %%
def guess_number():
    target_number = 77
    print(type(target_number))
    print(target_number)

# %%
guess_number()
# Out:
# <class 'int'>
# 77

# %%
def guess_number():
    question = input("Guess a number between 1-100")
    target_number = 77
    print(type(target_number))
    print(target_number)

# %%
guess_number()
# Out:
# Guess a number between 1-100 50
# <class 'int'>
# 77

# %%
def guess_number():
    question = input("Guess a number between 1-100:")
    question_output = int(question)
    target_number = 77
    if question_output == target_number:
        print("Correct! You win!")
    else:
        print("Try Again")

# %%
guess_number()
# Out:
# Guess a number between 1-100: 77
# Correct! You win!

# %%
guess_number()
# Out:
# Guess a number between 1-100: 50
# Try Again

# %%
def guess_number():
    question = input("Guess a number between 1-100:")
    question_output = int(question)
    target_number = 77
    
    for attempt in range(5):
        if question_output == target_number:
            print("Correct! You win!")
        else:
            print("Try Again")
    print("Out of attempts.")

# %%
guess_number()
# Out:
# Guess a number between 1-100: 1
# Try Again
# Try Again
# Try Again
# Try Again
# Try Again
# Out of attempts.

# %%
def guess_number():
    question = input("Guess a number between 1-100:")
    question_output = int(question)
    target_number = 77
    
    for x in range(5):
        if question_output == target_number:
            print("Correct! You win!")
        else:
            print("Try Again")
    print("Out of attempts.")

# %%
guess_number()
# Out:
# Guess a number between 1-100: 5
# Try Again
# Try Again
# Try Again
# Try Again
# Try Again
# Out of attempts.

# %%
def guess_number():
    target_number = 77
    
    for x in range(5):
        question = int(input("Guess a number between 1-100: "))
        
        if question == target_number:
            print("Correct! You win!")
            return
        else:
            print("Try Again")
            
    print("Out of attempts.")

# %%
 guess_number()
# Out:
# Guess a number between 1-100:  50
# Try Again
# Guess a number between 1-100:  50
# Try Again
# Guess a number between 1-100:  50
# Try Again
# Guess a number between 1-100:  50
# Try Again
# Guess a number between 1-100:  50
# Try Again
# Out of attempts.

# %%
# Out:
#   File <string>:10
#     print("Out of attempts.")
#                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
def guess_number():
    target_number = 77
    
    for x in range(5):
        question = int(input("Guess a number between 1-100: "))
        
        if question == target_number:
            print("Correct! You win!")
            return
        else:
            print("Try Again")
            
    print("Out of attempts.")

# %%
def guess_number():
    target_number = 77
    
    for x in range(5):
        question = int(input("Guess a number between 1-100: "))
        
        if question == target_number:
            print("Correct! You win!")
            return
        elif x == 3:
            print("Last attempt!")
        elif question < target_number:
            print("Guess is too low!")
        elif question > target_number:
            print("Guess is too high!")
        
            
    print("Out of attempts.")

# %%
guess_number()
# Out:
# Guess a number between 1-100:  7
# Guess is too low!
# Guess a number between 1-100:  99
# Guess is too high!
# Guess a number between 1-100:  50
# Guess is too low!
# Guess a number between 1-100:  3
# Last attempt!
# Guess a number between 1-100:  99
# Guess is too high!
# Out of attempts.
